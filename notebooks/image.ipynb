# %% [markdown]
# # Images

# %%
import requests

from IPython.display import display, Image

# %% [markdown]
# ## display by url

# %%
base_url = 'https://www.bing.com'
img_url = requests.get(f'{base_url}/HPImageArchive.aspx?format=js&idx=0&n=1').json()['images'][0]['url']
img_url = f'{base_url}{img_url}'
display(Image(url=img_url, width=320, height=240))
# Out:
# <img src="https://www.bing.com/th?id=OHR.FrostLeaves_ZH-CN6851974281_1920x1080.jpg&rf=LaDigue_1920x1080.jpg&pid=hp" width="320" height="240"/>

# %% [markdown]
# ## display by filename

# %%
display(Image(filename='static/img_01.jpeg'))
